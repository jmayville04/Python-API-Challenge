# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units="metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
      
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | hawaiian paradise park
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | kapa'a
# Processing Record 7 of Set 1 | wellington
# Processing Record 8 of Set 1 | ierapetra
# Processing Record 9 of Set 1 | mapastepec
# Processing Record 10 of Set 1 | margaret river
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | puerto natales
# Processing Record 13 of Set 1 | west island
# Processing Record 14 of Set 1 | tazacorte
# Processing Record 15 of Set 1 | novoshakhtinskiy
# Processing Record 16 of Set 1 | invercargill
# Processing Record 17 of Set 1 | bilibino
# Processing Record 18 of Set 1 | tura
# Processing Record 19 of Set 1 | san andres
# Processing Record 20 of Set 1 | cartagena
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | lospalos
# Processing Record 23 of Set 1 | puerto varas
# Processing Record 24 of Set 1 | blackmans bay
# Processing Record 25 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 26 of Set 1 | gadzhiyevo
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | ta`u
# Processing Record 29 of Set 1 | port-aux-francais
# Processing Record 30 of Set 1 | greymouth
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | kailua-kona
# Processing Record 33 of Set 1 | sao jose da coroa grande
# Processing Record 34 of Set 1 | iskateley
# Processing Record 35 of Set 1 | susuman
# Processing Record 36 of Set 1 | college
# Processing Record 37 of Set 1 | edinburgh of the seven seas
# Processing Record 38 of Set 1 | youhao
# Processing Record 39 of Set 1 | yelizovo
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | enewetak
# Processing Record 42 of Set 1 | papatowai
# Processing Record 43 of Set 1 | anadyr
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | isafjordur
# Processing Record 48 of Set 1 | lihue
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | rabo de peixe
# Processing Record 0 of Set 2 | kabinda
# Processing Record 1 of Set 2 | olonkinbyen
# Processing Record 2 of Set 2 | turaif
# Processing Record 3 of Set 2 | grytviken
# Processing Record 4 of Set 2 | yarmouth
# Processing Record 5 of Set 2 | al artawiyah
# Processing Record 6 of Set 2 | port mathurin
# Processing Record 7 of Set 2 | stanley
# Processing Record 8 of Set 2 | vilyuchinsk
# Processing Record 9 of Set 2 | holualoa
# Processing Record 10 of Set 2 | geraldton
# Processing Record 11 of Set 2 | udachny
# Processing Record 12 of Set 2 | el nido
# Processing Record 13 of Set 2 | rio cuarto
# Processing Record 14 of Set 2 | ar ruseris
# Processing Record 15 of Set 2 | adre
# Processing Record 16 of Set 2 | oroqen zizhiqi
# Processing Record 17 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 2 | vilyuysk
# Processing Record 19 of Set 2 | kristiansund
# Processing Record 20 of Set 2 | tralee
# Processing Record 21 of Set 2 | bechar
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | fort bragg
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | leshan
# Processing Record 26 of Set 2 | waitangi
# Processing Record 27 of Set 2 | tazovsky
# Processing Record 28 of Set 2 | nar'yan-mar
# Processing Record 29 of Set 2 | salinopolis
# Processing Record 30 of Set 2 | dudinka
# Processing Record 31 of Set 2 | port douglas
# Processing Record 32 of Set 2 | ust-nera
# Processing Record 33 of Set 2 | naze
# Processing Record 34 of Set 2 | arinos
# Processing Record 35 of Set 2 | midvagur
# Processing Record 36 of Set 2 | tuy hoa
# Processing Record 37 of Set 2 | codrington
# Processing Record 38 of Set 2 | ghardaia
# Processing Record 39 of Set 2 | macapa
# Processing Record 40 of Set 2 | valle de la pascua
# Processing Record 41 of Set 2 | tadine
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | acajutla
# Processing Record 44 of Set 2 | pisco
# Processing Record 45 of Set 2 | mekhe
# Processing Record 46 of Set 2 | tiksi
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | nadvoitsy
# Processing Record 49 of Set 2 | hami
# Processing Record 0 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | kegeyli shahar
# Processing Record 4 of Set 3 | whitehorse
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | campo gallo
# Processing Record 8 of Set 3 | zagora
# Processing Record 9 of Set 3 | touros
# Processing Record 10 of Set 3 | sanctuary point
# Processing Record 11 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 12 of Set 3 | acigol
# City not found. Skipping...
# Processing Record 13 of Set 3 | praia da vitoria
# Processing Record 14 of Set 3 | yerofey pavlovich
# Processing Record 15 of Set 3 | akureyri
# Processing Record 16 of Set 3 | mejit
# Processing Record 17 of Set 3 | lucaya
# Processing Record 18 of Set 3 | pacific grove
# Processing Record 19 of Set 3 | saint-pierre
# Processing Record 20 of Set 3 | egilsstadir
# Processing Record 21 of Set 3 | naivasha
# Processing Record 22 of Set 3 | tolanaro
# Processing Record 23 of Set 3 | rikaze
# Processing Record 24 of Set 3 | nuku'alofa
# Processing Record 25 of Set 3 | strezhevoy
# Processing Record 26 of Set 3 | punta arenas
# Processing Record 27 of Set 3 | irinjalakuda
# Processing Record 28 of Set 3 | luanda
# Processing Record 29 of Set 3 | haiku-pauwela
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | toliara
# Processing Record 32 of Set 3 | san pedro pochutla
# Processing Record 33 of Set 3 | oamaru
# Processing Record 34 of Set 3 | jalalabad
# Processing Record 35 of Set 3 | shingu
# Processing Record 36 of Set 3 | sinabang
# Processing Record 37 of Set 3 | coquimbo
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | acarau
# Processing Record 40 of Set 3 | al jawf
# Processing Record 41 of Set 3 | selfoss
# Processing Record 42 of Set 3 | woolgoolga
# Processing Record 43 of Set 3 | port saint john's
# Processing Record 44 of Set 3 | aasiaat
# Processing Record 45 of Set 3 | santa lucia
# Processing Record 46 of Set 3 | rio grande
# Processing Record 47 of Set 3 | gisborne
# Processing Record 48 of Set 3 | sao joao da barra
# Processing Record 49 of Set 3 | saipan
# Processing Record 0 of Set 4 | fortuna
# Processing Record 1 of Set 4 | kununurra
# Processing Record 2 of Set 4 | qulsary
# Processing Record 3 of Set 4 | zakamensk
# Processing Record 4 of Set 4 | puerto baquerizo moreno
# Processing Record 5 of Set 4 | atafu village
# Processing Record 6 of Set 4 | mammoth lakes
# Processing Record 7 of Set 4 | cambridge
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | miguel ahumada
# Processing Record 10 of Set 4 | midland
# Processing Record 11 of Set 4 | minas de marcona
# Processing Record 12 of Set 4 | as sulayyil
# Processing Record 13 of Set 4 | nyala
# Processing Record 14 of Set 4 | luau
# Processing Record 15 of Set 4 | kerikeri
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | polyarnyy
# Processing Record 18 of Set 4 | valparaiso
# Processing Record 19 of Set 4 | myitkyina
# Processing Record 20 of Set 4 | la sarre
# Processing Record 21 of Set 4 | labytnangi
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | bezenchuk
# Processing Record 24 of Set 4 | nieuw amsterdam
# Processing Record 25 of Set 4 | mednogorsk
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | chonchi
# Processing Record 28 of Set 4 | hadibu
# Processing Record 29 of Set 4 | sisimiut
# Processing Record 30 of Set 4 | urangan
# Processing Record 31 of Set 4 | xining
# Processing Record 32 of Set 4 | conde
# Processing Record 33 of Set 4 | almonte
# Processing Record 34 of Set 4 | la'ie
# Processing Record 35 of Set 4 | utrik
# Processing Record 36 of Set 4 | queenstown
# Processing Record 37 of Set 4 | vernon
# Processing Record 38 of Set 4 | tarakan
# Processing Record 39 of Set 4 | calama
# Processing Record 40 of Set 4 | tsiombe
# Processing Record 41 of Set 4 | gorontalo
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | singtam
# Processing Record 44 of Set 4 | dongola
# Processing Record 45 of Set 4 | robbah
# Processing Record 46 of Set 4 | buon ma thuot
# Processing Record 47 of Set 4 | hoemul-li
# Processing Record 48 of Set 4 | vaskelovo
# Processing Record 49 of Set 4 | puerto colombia
# Processing Record 0 of Set 5 | gislaved
# Processing Record 1 of Set 5 | kukmor
# Processing Record 2 of Set 5 | bikenibeu village
# Processing Record 3 of Set 5 | ouro preto do oeste
# Processing Record 4 of Set 5 | mil'kovo
# Processing Record 5 of Set 5 | fort mcmurray
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | barcelos
# Processing Record 9 of Set 5 | kalmunai
# Processing Record 10 of Set 5 | aykhal
# Processing Record 11 of Set 5 | uturoa
# Processing Record 12 of Set 5 | checker hall
# City not found. Skipping...
# Processing Record 13 of Set 5 | arti
# Processing Record 14 of Set 5 | lata
# Processing Record 15 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 16 of Set 5 | mogocha
# Processing Record 17 of Set 5 | diawara
# Processing Record 18 of Set 5 | qui nhon
# Processing Record 19 of Set 5 | chui
# Processing Record 20 of Set 5 | colonia
# Processing Record 21 of Set 5 | bredasdorp
# Processing Record 22 of Set 5 | port alfred
# Processing Record 23 of Set 5 | colonia menno
# Processing Record 24 of Set 5 | alofi
# Processing Record 25 of Set 5 | christchurch
# Processing Record 26 of Set 5 | payyannur
# Processing Record 27 of Set 5 | farasan
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | wailua homesteads
# Processing Record 30 of Set 5 | east london
# Processing Record 31 of Set 5 | villamontes
# Processing Record 32 of Set 5 | rayadrug
# Processing Record 33 of Set 5 | natal
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | arraial do cabo
# Processing Record 36 of Set 5 | suva
# Processing Record 37 of Set 5 | sao jose de piranhas
# Processing Record 38 of Set 5 | ulysses
# Processing Record 39 of Set 5 | wuxue
# Processing Record 40 of Set 5 | ndioum
# Processing Record 41 of Set 5 | murray bridge
# Processing Record 42 of Set 5 | newman
# Processing Record 43 of Set 5 | vorkuta
# Processing Record 44 of Set 5 | quellon
# Processing Record 45 of Set 5 | yantzaza
# Processing Record 46 of Set 5 | sao paulo de olivenca
# Processing Record 47 of Set 5 | tshikapa
# Processing Record 48 of Set 5 | amal
# Processing Record 49 of Set 5 | sabha
# Processing Record 0 of Set 6 | reichenbach an der fils
# Processing Record 1 of Set 6 | glogovac
# Processing Record 2 of Set 6 | kassala
# Processing Record 3 of Set 6 | kotma
# Processing Record 4 of Set 6 | shelkovskaya
# Processing Record 5 of Set 6 | guerrero negro
# Processing Record 6 of Set 6 | chinde
# Processing Record 7 of Set 6 | saint-joseph
# Processing Record 8 of Set 6 | neryungri
# Processing Record 9 of Set 6 | itoman
# Processing Record 10 of Set 6 | sayyan
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | sandnessjoen
# Processing Record 13 of Set 6 | pizarro
# Processing Record 14 of Set 6 | yanzhou
# Processing Record 15 of Set 6 | brookings
# Processing Record 16 of Set 6 | happy valley-goose bay
# Processing Record 17 of Set 6 | kencong
# Processing Record 18 of Set 6 | island harbour
# Processing Record 19 of Set 6 | beloyarskiy
# Processing Record 20 of Set 6 | pioner
# Processing Record 21 of Set 6 | thunder bay
# Processing Record 22 of Set 6 | coahuayana de hidalgo
# Processing Record 23 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 6 | saynshand
# Processing Record 25 of Set 6 | puerto lempira
# Processing Record 26 of Set 6 | melekeok village
# Processing Record 27 of Set 6 | kaa-khem
# Processing Record 28 of Set 6 | shendi
# Processing Record 29 of Set 6 | boguchany
# Processing Record 30 of Set 6 | afaahiti
# Processing Record 31 of Set 6 | orosei
# Processing Record 32 of Set 6 | puerto deseado
# Processing Record 33 of Set 6 | vila velha
# Processing Record 34 of Set 6 | keningau
# Processing Record 35 of Set 6 | cananeia
# Processing Record 36 of Set 6 | sitka
# Processing Record 37 of Set 6 | formosa
# Processing Record 38 of Set 6 | bontang
# Processing Record 39 of Set 6 | peace river
# Processing Record 40 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 41 of Set 6 | champerico
# Processing Record 42 of Set 6 | sarina
# Processing Record 43 of Set 6 | jiuquan
# Processing Record 44 of Set 6 | kingscliff
# Processing Record 45 of Set 6 | antsiranana
# Processing Record 46 of Set 6 | samraong
# Processing Record 47 of Set 6 | porto novo
# Processing Record 48 of Set 6 | ca mau
# Processing Record 49 of Set 6 | chalchihuapan
# City not found. Skipping...
# Processing Record 0 of Set 7 | nikolayevsk-on-amure
# Processing Record 1 of Set 7 | nagqu
# Processing Record 2 of Set 7 | bedesa
# Processing Record 3 of Set 7 | san luis de la loma
# Processing Record 4 of Set 7 | parun
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | yardimli
# Processing Record 7 of Set 7 | mezhdurechenskiy
# Processing Record 8 of Set 7 | kirensk
# Processing Record 9 of Set 7 | murghob
# Processing Record 10 of Set 7 | port-vila
# Processing Record 11 of Set 7 | la passe
# Processing Record 12 of Set 7 | labrador city
# Processing Record 13 of Set 7 | tarauaca
# Processing Record 14 of Set 7 | brisas de zicatela
# Processing Record 15 of Set 7 | bischofshofen
# Processing Record 16 of Set 7 | ngetkib
# Processing Record 17 of Set 7 | tidjikja
# Processing Record 18 of Set 7 | howard springs
# Processing Record 19 of Set 7 | santa maria
# Processing Record 20 of Set 7 | moires
# Processing Record 21 of Set 7 | russellville
# Processing Record 22 of Set 7 | fisterra
# Processing Record 23 of Set 7 | merritt
# Processing Record 24 of Set 7 | callao
# Processing Record 25 of Set 7 | laojunmiao
# Processing Record 26 of Set 7 | san fernando de apure
# Processing Record 27 of Set 7 | belmonte
# Processing Record 28 of Set 7 | menongue
# Processing Record 29 of Set 7 | mountain home
# Processing Record 30 of Set 7 | pandan
# Processing Record 31 of Set 7 | panjab
# Processing Record 32 of Set 7 | karratha
# Processing Record 33 of Set 7 | kingston
# Processing Record 34 of Set 7 | arawa
# Processing Record 35 of Set 7 | minas de matahambre
# City not found. Skipping...
# Processing Record 36 of Set 7 | wakkanai
# Processing Record 37 of Set 7 | archangelos
# Processing Record 38 of Set 7 | beibei
# Processing Record 39 of Set 7 | hell-ville
# Processing Record 40 of Set 7 | clinton
# Processing Record 41 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 42 of Set 7 | cururupu
# Processing Record 43 of Set 7 | bulayevo
# Processing Record 44 of Set 7 | saint croix
# Processing Record 45 of Set 7 | san rafael
# Processing Record 46 of Set 7 | northam
# Processing Record 47 of Set 7 | comodoro rivadavia
# Processing Record 48 of Set 7 | remire-montjoly
# Processing Record 49 of Set 7 | ola
# Processing Record 0 of Set 8 | port macquarie
# Processing Record 1 of Set 8 | al kharijah
# Processing Record 2 of Set 8 | north bend
# Processing Record 3 of Set 8 | vila franca do campo
# Processing Record 4 of Set 8 | zeya
# Processing Record 5 of Set 8 | g'ijduvon shahri
# City not found. Skipping...
# Processing Record 6 of Set 8 | lafollette
# Processing Record 7 of Set 8 | port moresby
# Processing Record 8 of Set 8 | conceicao da barra
# Processing Record 9 of Set 8 | kupang
# Processing Record 10 of Set 8 | pukchil-lodongjagu
# Processing Record 11 of Set 8 | cockburn town
# Processing Record 12 of Set 8 | san martin de los andes
# Processing Record 13 of Set 8 | bage
# Processing Record 14 of Set 8 | gadani
# Processing Record 15 of Set 8 | alajarvi
# Processing Record 16 of Set 8 | charlottetown
# Processing Record 17 of Set 8 | villa gesell
# Processing Record 18 of Set 8 | flying fish cove
# Processing Record 19 of Set 8 | mora
# Processing Record 20 of Set 8 | santa isabel
# Processing Record 21 of Set 8 | st. john's
# Processing Record 22 of Set 8 | oodweyne
# Processing Record 23 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 8 | la arena
# Processing Record 25 of Set 8 | nova sintra
# Processing Record 26 of Set 8 | tallulah
# Processing Record 27 of Set 8 | khandyga
# Processing Record 28 of Set 8 | quetta
# Processing Record 29 of Set 8 | noosa heads
# Processing Record 30 of Set 8 | kaman
# Processing Record 31 of Set 8 | glenvale
# Processing Record 32 of Set 8 | kas
# Processing Record 33 of Set 8 | guatrache
# Processing Record 34 of Set 8 | smithers
# Processing Record 35 of Set 8 | baie-comeau
# Processing Record 36 of Set 8 | mount pearl
# Processing Record 37 of Set 8 | novodvinsk
# Processing Record 38 of Set 8 | manicore
# Processing Record 39 of Set 8 | kone
# Processing Record 40 of Set 8 | tipasa
# Processing Record 41 of Set 8 | al-`ula
# City not found. Skipping...
# Processing Record 42 of Set 8 | tindouf
# Processing Record 43 of Set 8 | qal'at bishah
# City not found. Skipping...
# Processing Record 44 of Set 8 | bosaso
# Processing Record 45 of Set 8 | canmore
# Processing Record 46 of Set 8 | barra de santo antonio
# Processing Record 47 of Set 8 | cabeza del buey
# Processing Record 48 of Set 8 | verkhniy baskunchak
# Processing Record 49 of Set 8 | al bawiti
# Processing Record 0 of Set 9 | kyzyl
# Processing Record 1 of Set 9 | harstad
# Processing Record 2 of Set 9 | verkhnevilyuysk
# Processing Record 3 of Set 9 | friedland
# Processing Record 4 of Set 9 | bowen
# Processing Record 5 of Set 9 | broken hill
# Processing Record 6 of Set 9 | klyuchi
# Processing Record 7 of Set 9 | iguape
# Processing Record 8 of Set 9 | minab
# Processing Record 9 of Set 9 | parintins
# Processing Record 10 of Set 9 | bukittinggi
# Processing Record 11 of Set 9 | luynes
# Processing Record 12 of Set 9 | isakogorka
# City not found. Skipping...
# Processing Record 13 of Set 9 | harper
# Processing Record 14 of Set 9 | fengrun
# Processing Record 15 of Set 9 | naifaru
# Processing Record 16 of Set 9 | alice springs
# Processing Record 17 of Set 9 | bushland beach
# City not found. Skipping...
# Processing Record 18 of Set 9 | port lincoln
# Processing Record 19 of Set 9 | ordos
# City not found. Skipping...
# Processing Record 20 of Set 9 | fortaleza
# Processing Record 21 of Set 9 | edd
# Processing Record 22 of Set 9 | kourou
# Processing Record 23 of Set 9 | camacupa
# Processing Record 24 of Set 9 | nirmal
# Processing Record 25 of Set 9 | yung shue wan
# Processing Record 26 of Set 9 | oualidia
# City not found. Skipping...
# Processing Record 27 of Set 9 | tala
# Processing Record 28 of Set 9 | palikir - national government center
# Processing Record 29 of Set 9 | ponta delgada
# Processing Record 30 of Set 9 | belyy yar
# Processing Record 31 of Set 9 | horta
# Processing Record 32 of Set 9 | mahajanga
# Processing Record 33 of Set 9 | vorgashor
# Processing Record 34 of Set 9 | bonthe
# Processing Record 35 of Set 9 | acapulco de juarez
# Processing Record 36 of Set 9 | omuthiya
# City not found. Skipping...
# Processing Record 37 of Set 9 | paracuru
# Processing Record 38 of Set 9 | cidreira
# Processing Record 39 of Set 9 | nova vicosa
# Processing Record 40 of Set 9 | zvenigorod
# Processing Record 41 of Set 9 | inongo
# Processing Record 42 of Set 9 | mogadishu
# Processing Record 43 of Set 9 | altamira
# Processing Record 44 of Set 9 | the bottom
# Processing Record 45 of Set 9 | lashio
# Processing Record 46 of Set 9 | kuqa
# Processing Record 47 of Set 9 | whakatane
# Processing Record 48 of Set 9 | coihueco
# Processing Record 49 of Set 9 | farah
# Processing Record 0 of Set 10 | mount gambier
# Processing Record 1 of Set 10 | freetown
# Processing Record 2 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 3 of Set 10 | papao
# Processing Record 4 of Set 10 | churapcha
# Processing Record 5 of Set 10 | nirasaki
# Processing Record 6 of Set 10 | carutapera
# Processing Record 7 of Set 10 | port sudan
# Processing Record 8 of Set 10 | lewiston orchards
# Processing Record 9 of Set 10 | las khorey
# Processing Record 10 of Set 10 | port victoria
# Processing Record 11 of Set 10 | sarmiento
# Processing Record 12 of Set 10 | kuanda
# Processing Record 13 of Set 10 | deschutes river woods
# Processing Record 14 of Set 10 | mata-utu
# Processing Record 15 of Set 10 | bridgewater
# Processing Record 16 of Set 10 | pekalongan
# Processing Record 17 of Set 10 | det udom
# Processing Record 18 of Set 10 | dila
# Processing Record 19 of Set 10 | sayan
# Processing Record 20 of Set 10 | fallon
# Processing Record 21 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 22 of Set 10 | kurumkan
# Processing Record 23 of Set 10 | zyryanskoye
# Processing Record 24 of Set 10 | jieshi
# Processing Record 25 of Set 10 | aripuana
# Processing Record 26 of Set 10 | ulaangom
# Processing Record 27 of Set 10 | vadso
# Processing Record 28 of Set 10 | bamboo flat
# Processing Record 29 of Set 10 | tamanrasset
# Processing Record 30 of Set 10 | petawawa
# Processing Record 31 of Set 10 | chu
# Processing Record 32 of Set 10 | shirvan
# Processing Record 33 of Set 10 | north platte
# Processing Record 34 of Set 10 | belgrade
# Processing Record 35 of Set 10 | dedougou
# Processing Record 36 of Set 10 | punta de bombon
# Processing Record 37 of Set 10 | esqueda
# Processing Record 38 of Set 10 | belev
# Processing Record 39 of Set 10 | ocean city
# Processing Record 40 of Set 10 | badger
# Processing Record 41 of Set 10 | tumut
# Processing Record 42 of Set 10 | ajdabiya
# Processing Record 43 of Set 10 | ylitornio
# Processing Record 44 of Set 10 | betio village
# Processing Record 45 of Set 10 | kodok
# City not found. Skipping...
# Processing Record 46 of Set 10 | eydhafushi
# Processing Record 47 of Set 10 | qaqortoq
# Processing Record 48 of Set 10 | rethymno
# Processing Record 49 of Set 10 | yuzhno-kurilsk
# Processing Record 0 of Set 11 | kertih
# Processing Record 1 of Set 11 | kenai
# Processing Record 2 of Set 11 | alness
# Processing Record 3 of Set 11 | loikaw
# Processing Record 4 of Set 11 | tottori
# Processing Record 5 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 6 of Set 11 | standerton
# Processing Record 7 of Set 11 | zouerate
# Processing Record 8 of Set 11 | franeker
# Processing Record 9 of Set 11 | santo angelo
# Processing Record 10 of Set 11 | chacabuco
# Processing Record 11 of Set 11 | raurkela
# City not found. Skipping...
# Processing Record 12 of Set 11 | westport
# Processing Record 13 of Set 11 | constantia
# Processing Record 14 of Set 11 | al ghayzah
# Processing Record 15 of Set 11 | alem paraiba
# Processing Record 16 of Set 11 | weining
# Processing Record 17 of Set 11 | nadym
# Processing Record 18 of Set 11 | grand falls-windsor
# Processing Record 19 of Set 11 | buenos aires
# Processing Record 20 of Set 11 | kapuskasing
# Processing Record 21 of Set 11 | newcastle west
# Processing Record 22 of Set 11 | slave lake
# Processing Record 23 of Set 11 | severnoye
# Processing Record 24 of Set 11 | lebu
# Processing Record 25 of Set 11 | madalena
# Processing Record 26 of Set 11 | umluj
# Processing Record 27 of Set 11 | gurmatkal
# Processing Record 28 of Set 11 | victoria
# Processing Record 29 of Set 11 | ancud
# Processing Record 30 of Set 11 | camana
# Processing Record 31 of Set 11 | weno
# Processing Record 32 of Set 11 | boende
# Processing Record 33 of Set 11 | sao vicente
# Processing Record 34 of Set 11 | hasaki
# Processing Record 35 of Set 11 | surovikino
# Processing Record 36 of Set 11 | torbat-e heydariyeh
# Processing Record 37 of Set 11 | keflavik
# Processing Record 38 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 39 of Set 11 | kurchatov
# Processing Record 40 of Set 11 | ad dawadimi
# Processing Record 41 of Set 11 | buala
# Processing Record 42 of Set 11 | abepura
# Processing Record 43 of Set 11 | 'alaqahdari dishu
# Processing Record 44 of Set 11 | nafada
# Processing Record 45 of Set 11 | severo-yeniseyskiy
# Processing Record 46 of Set 11 | carbonear
# Processing Record 47 of Set 11 | bhitarwar
# Processing Record 48 of Set 11 | ijuw
# City not found. Skipping...
# Processing Record 49 of Set 11 | oranjemund
# Processing Record 0 of Set 12 | hua hin
# Processing Record 1 of Set 12 | lijiang
# Processing Record 2 of Set 12 | burutu
# Processing Record 3 of Set 12 | kalifornsky
# Processing Record 4 of Set 12 | saudarkrokur
# Processing Record 5 of Set 12 | kyshtovka
# Processing Record 6 of Set 12 | safford
# Processing Record 7 of Set 12 | buta
# Processing Record 8 of Set 12 | karwar
# Processing Record 9 of Set 12 | durban
# Processing Record 10 of Set 12 | rochester
# Processing Record 11 of Set 12 | broome
# Processing Record 12 of Set 12 | nogliki
# Processing Record 13 of Set 12 | marat
# Processing Record 14 of Set 12 | kerema
# Processing Record 15 of Set 12 | sainte-anne-des-monts
# Processing Record 16 of Set 12 | urgut shahri
# City not found. Skipping...
# Processing Record 17 of Set 12 | kuhmo
# Processing Record 18 of Set 12 | namdrik
# Processing Record 19 of Set 12 | morant bay
# Processing Record 20 of Set 12 | lorengau
# Processing Record 21 of Set 12 | lintong
# Processing Record 22 of Set 12 | tukrah
# Processing Record 23 of Set 12 | eureka
# Processing Record 24 of Set 12 | hengchun
# Processing Record 25 of Set 12 | saijo
# Processing Record 26 of Set 12 | sake
# Processing Record 27 of Set 12 | daru
# Processing Record 28 of Set 12 | arteche
# Processing Record 29 of Set 12 | rongelap
# Processing Record 30 of Set 12 | terrace
# Processing Record 31 of Set 12 | mar del plata
# Processing Record 32 of Set 12 | inarajan village
# Processing Record 33 of Set 12 | machico
# Processing Record 34 of Set 12 | inhambane
# Processing Record 35 of Set 12 | bayan nur
# City not found. Skipping...
# Processing Record 36 of Set 12 | mao
# Processing Record 37 of Set 12 | sievi
# Processing Record 38 of Set 12 | okhotsk
# Processing Record 39 of Set 12 | parma
# Processing Record 40 of Set 12 | sassandra
# Processing Record 41 of Set 12 | weihai
# Processing Record 42 of Set 12 | ribeira brava
# Processing Record 43 of Set 12 | awjilah
# Processing Record 44 of Set 12 | ketchikan
# Processing Record 45 of Set 12 | korsakov
# Processing Record 46 of Set 12 | chipinge
# Processing Record 47 of Set 12 | figuig (centre)
# Processing Record 48 of Set 12 | redding
# Processing Record 49 of Set 12 | bodaybo
# Processing Record 0 of Set 13 | celestun
# Processing Record 1 of Set 13 | las tablas
# Processing Record 2 of Set 13 | tangalle
# Processing Record 3 of Set 13 | salavan
# Processing Record 4 of Set 13 | tyumen
# Processing Record 5 of Set 13 | minot
# Processing Record 6 of Set 13 | kavieng
# Processing Record 7 of Set 13 | tual
# Processing Record 8 of Set 13 | gulf shores
# Processing Record 9 of Set 13 | ushtobe
# Processing Record 10 of Set 13 | kismayo
# Processing Record 11 of Set 13 | kindu
# Processing Record 12 of Set 13 | sabang
# Processing Record 13 of Set 13 | bremen
# Processing Record 14 of Set 13 | fandriana
# Processing Record 15 of Set 13 | batouri
# Processing Record 16 of Set 13 | zell am see
# Processing Record 17 of Set 13 | biryusinsk
# Processing Record 18 of Set 13 | altai
# Processing Record 19 of Set 13 | kalyazin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                    georgetown   5.4112  100.3354     31.08        66
# 1                     adamstown -25.0660 -130.1015     25.01        85
# 2        hawaiian paradise park  19.5933 -154.9731     25.73        75
# 3                       iqaluit  63.7506  -68.5145    -19.15        78
# 4                        avarua -21.2078 -159.7750     29.03        65
# ...                         ...      ...       ...       ...       ...
# 585                     batouri   4.4333   14.3667     23.18        29
# 586                 zell am see  47.3256   12.7944      0.10         1
# 587                  biryusinsk  55.9634   97.8235    -12.99        86
# 588                       altai  46.3722   96.2583    -16.70        57
# 589                    kalyazin  57.2403   37.8433    -21.22        97
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        4.12      MY  1707878573
# 1               100        6.69      PN  1707878604
# 2               100        3.09      US  1707878604
# 3                75        0.00      CA  1707878604
# 4                40        4.12      CK  1707878604
# ...             ...         ...     ...         ...
# 585             100        1.39      CM  1707878675
# 586              99        2.17      AT  1707878676
# 587             100        2.30      RU  1707878676
# 588               0        1.16      MN  1707878676
# 589              20        3.51      RU  1707878676
#
# [590 rows x 9 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],edgecolors="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],edgecolors="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],edgecolors="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],edgecolors="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=12, color='red')
    plt.xlabel(x_values.name)
    plt.ylabel(y_values.name)
    plt.title(f"{x_values.name} vs. {y_values.name}")

# %%
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                    georgetown   5.4112  100.3354     31.08        66
# 1                     adamstown -25.0660 -130.1015     25.01        85
# 2        hawaiian paradise park  19.5933 -154.9731     25.73        75
# 3                       iqaluit  63.7506  -68.5145    -19.15        78
# 4                        avarua -21.2078 -159.7750     29.03        65
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        4.12      MY  1707878573
# 1               100        6.69      PN  1707878604
# 2               100        3.09      US  1707878604
# 3                75        0.00      CA  1707878604
# 4                40        4.12      CK  1707878604

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                    georgetown   5.4112  100.3354     31.08        66
# 2        hawaiian paradise park  19.5933 -154.9731     25.73        75
# 3                       iqaluit  63.7506  -68.5145    -19.15        78
# 5                        kapa'a  22.0752 -159.3190     25.99        71
# 7                     ierapetra  35.0100   25.7353     13.41        71
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        4.12      MY  1707878573
# 2               100        3.09      US  1707878604
# 3                75        0.00      CA  1707878604
# 5                 0        7.20      US  1707878605
# 7                 1        2.68      GR  1707878605

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             adamstown -25.0660 -130.1015     25.01        85         100
# 4                avarua -21.2078 -159.7750     29.03        65          40
# 6            wellington -41.2866  174.7756     20.81        61          20
# 9        margaret river -33.9500  115.0667     24.46        41          77
# 11       puerto natales -51.7236  -72.4875     10.19        99         100
#
#          Wind Speed Country        Date
# City_ID
# 1              6.69      PN  1707878604
# 4              4.12      CK  1707878604
# 6             12.35      NZ  1707878394
# 9              1.29      AU  1707878605
# 11             0.55      CL  1707878605

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
